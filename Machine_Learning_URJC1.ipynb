# %% [markdown]
# <a href="https://colab.research.google.com/github/mjrmedina/Master_URJC/blob/master/Machine_Learning_URJC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
import pandas as pd

file='/gdrive/My Drive/Colab Notebooks/input/Datos_Eleciones_Generales_Provincias.csv'
df = pd.read_csv(file)

df.head()
# Out:
#    IDPROV  ... Otros2016
# 0       1  ...     27.91
# 1       2  ...      2.12
# 2       3  ...      3.00
# 3       4  ...      2.42
# 4       5  ...      2.11
#
# [5 rows x 62 columns]

# %%
df['Provincia'] = df['NombreProv'].str.strip()
df.head()
# Out:
#    IDPROV  ...           Provincia
# 0       1  ...       Araba - Álava
# 1       2  ...            Albacete
# 2       3  ...  Alicante / Alacant
# 3       4  ...             Almería
# 4       5  ...               Ávila
#
# [5 rows x 64 columns]

# %%
df[df['Censo2000'] > 1000000]

df[(df['Censo2000'] > 1000000)& (df['PP_2000'] > df['PSOE_2000'])]
# Out:
#     IDPROV  ... Otros2016
# 2        3  ...      3.00
# 14      15  ...      5.70
# 27      28  ...      3.10
# 28      29  ...      3.39
# 45      46  ...      3.61
#
# [5 rows x 62 columns]

# %%
df['Censo_Total'] = df['Censo1996'] + df['Censo2000'] + df['Censo2004'] + df['Censo2008'] + df['Censo2011'] + df['Censo2016']

# %%
df['Censo_Total']
# Out:
# 0      478049
# 1      578956
# 2     2132806
# 3      786440
# 4      290061
# 5     1050397
# 6     1258338
# 7     7938272
# 8      604338
# 9      684093
# 10    1732118
# 11     761062
# 12     777776
# 13    1225850
# 14    2012584
# 15     336809
# 16     886814
# 17    1347219
# 18     265875
# 19    1156134
# 20     726408
# 21     355296
# 22    1032479
# 23     887528
# 24     614507
# 25     452010
# 26     682340
# 27    8516945
# 28    1927267
# 29    1777522
# 30     907986
# 31     674594
# 32    1939916
# 33     307923
# 34    1365927
# 35    1592926
# 36     622708
# 37    1303397
# 38     910541
# 39     250775
# 40    2715580
# 41     159127
# 42     953603
# 43     237550
# 44     834790
# 45    3655166
# 46     841463
# 47    1952163
# 48     367098
# 49    1431401
# 50     107146
# 51      93400
# Name: Censo_Total, dtype: int64

# %%
df.columns

result = [i for i in df.columns if i.startswith('Censo')]

print(result)
# Out:
# ['Censo1996', 'Censo2000', 'Censo2004', 'Censo2008', 'Censo2011', 'Censo2016', 'Censo_Total']

# %%
df['Provincia_Reducida'] =  df['Provincia'].str[:3]
df['Provincia_Reducida']
# Out:
# 0     Ara
# 1     Alb
# 2     Ali
# 3     Alm
# 4     Ávi
# 5     Bad
# 6     Ill
# 7     Bar
# 8     Bur
# 9     Các
# 10    Cád
# 11    Cas
# 12    Ciu
# 13    Cór
# 14    A C
# 15    Cue
# 16    Gir
# 17    Gra
# 18    Gua
# 19    Gip
# 20    Hue
# 21    Hue
# 22    Jaé
# 23    Leó
# 24    Lle
# 25    La
# 26    Lug
# 27    Mad
# 28    Mál
# 29    Mur
# 30    Nav
# 31    Our
# 32    Ast
# 33    Pal
# 34    Las
# 35    Pon
# 36    Sal
# 37    San
# 38    Can
# 39    Seg
# 40    Sev
# 41    Sor
# 42    Tar
# 43    Ter
# 44    Tol
# 45    Val
# 46    Val
# 47    Biz
# 48    Zam
# 49    Zar
# 50    Ceu
# 51    Mel
# Name: Provincia_Reducida, dtype: object

# %%
import altair as alt

alt.Chart(df).mark_bar().encode(
  x='Provincia',
  y='Censo2000'
).interactive(bind_y=False)
# Out:
# Chart({
#   data:     IDPROV  ... Provincia_Reducida
#   0        1  ...                Ara
#   1        2  ...                Alb
#   2        3  ...                Ali
#   3        4  ...                Alm
#   4        5  ...                Ávi
#   5        6  ...                Bad
#   6        7  ...                Ill
#   7        8  ...                Bar
#   8        9  ...                Bur
#   9       10  ...                Các
#   10      11  ...                Cád
#   11      12  ...                Cas
#   12      13  ...                Ciu
#   13      14  ...                Cór
#   14      15  ...                A C
#   15      16  ...                Cue
#   16      17  ...                Gir
#   17      18  ...                Gra
#   18      19  ...                Gua
#   19      20  ...                Gip
#   20      21  ...                Hue
#   21      22  ...                Hue
#   22      23  ...                Jaé
#   23      24  ...                Leó
# ...

# %%
import matplotlib.pyplot as plt

df10 = df.head(10)

labels = 'S1', 'S2', 'S3'
sections = [56, 66, 24]
colors = ['c', 'g', 'y']

plt.pie(df10['Censo2000'], labels=df10['Provincia'], colors=colors,
        startangle=90,
        autopct = '%1.2f%%')

plt.axis('equal') # Try commenting this out.
plt.title('Top 10 Provincias Top 10')
plt.show()

# %%
lista_columnas=['PP_2000','PSOE_2000','IU_2000']
filtrado = df[df['Provincia']=='Zamora']
filtrado
ultra_filtrado = filtrado[lista_columnas]
ultra_filtrado
# Out:
#     PP_2000  PSOE_2000  IU_2000
# 48    58.83      32.44     2.84

# %%
import matplotlib.pyplot as plt


labels = 'S1', 'S2', 'S3'
sections = [58, 32, 2]
colors = ['c', 'g', 'y']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        autopct = '%1.2f%%')

#plt.axis('equal') # Try commenting this out.
plt.title('Ejemplo de Pie')
plt.show()
